# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
word=input("Enter your chars: ")
for i in range(len(word)):
    if word.count(word[i])>=2: 
        continue
    elif word.count(word[i])==1: 
        print(i)
        break
else: print("-1")
